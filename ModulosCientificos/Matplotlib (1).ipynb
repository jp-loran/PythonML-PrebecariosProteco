# %% [markdown]
# ## Maplotlib
#
# Es una biblioteca de python dedicada a la graficación en 2D. La filosofia de Matplotlib es hacer las cosas faciles y las dificiles posibles.
#
# ### Figure
#
# Figure es una clase del paquete matplotlib.pyplot. Figure es la clase donde estaremos utilizando todas las demas clases hijas. Es la ventana donde estará la gráfica, ejes
#
# ![](../img/img_06.png)
#
# Algunos de los parametros mas importantes de figure
#
# | Nombre    | Descripcion                                      |
# |-----------|--------------------------------------------------|
# | figsize   | Recibe una tupla con las dimensiones en pulgadas |
# | linewidth | Recibe la anchura del frame                      |
# | dpi       | Define cantidad de puntos por pulgada.           |

# %%
# Utilizamos este comando para especificar a matplotlib que sera usado en jupyter 
#% matplotlib notebook 

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Plot
#
# La función plot , retorna una lista de objetos de linea. Recibe como parametros arreglos de NumPy.
#
# Se utiliza en su mayoria para realizar gráficas simples.

# %%
x = np.linspace(0, 2, 100)
#Gráficamos (x,x) y colocamos la etiqueta "Linea recta"
plt.plot(x, x, label = 'Linea Recta', color="silver")
#(x, x al cuadrado)
plt.plot(x, x ** 2, label = "Cuadrada", color="olivedrab")
#(x, x cúbica)
plt.plot(x, x ** 3, label = 'Cúbica', color="darkmagenta")
plt.legend()

plt.xlabel('eje x')
plt.ylabel('eje y')
plt.show()

# %% [markdown]
# **Colores en matplotlib**
#
# El uso de colores se hace a través de palabras reservadas, es importante notar que para los colores más comunes existen nombres de una letra como g (green/verde), c (cyan/ciano), r (red/rojo), entre otros.
# ![Palabras reservadas para colores](https://drive.google.com/uc?id=1bTRpwDiq2u9UHoljjGFYngnJv_pQ_LG0)

# %%
import numpy as np
# Variable independiente
x = np.arange(0, 10, 0.2)

# Variable dependiente
y = np.sin(x)

# Creando la figura para tener donde graficar
fig = plt.figure()

fig.suptitle("Grafica") # Agrega titulo a la figura

plt.grid() # La funcion grid cuadricula el axes sobre el figure 

# Asignando los valores para graficar en plot
fig = plt.plot(x, y) 

# Asignamos nombres a los ejes
plt.xlabel('x')
plt.ylabel('Sen(x)')

# Desplazara lo contenido que esta almacenado en Figure
plt.show()

# %%
# Variable dependiente
y = np.sin(x)

# Creando la figura para tener donde graficar
fig = plt.figure()

fig.suptitle("Diagrama de dispersion") # Agrega titulo a la figura

plt.grid() # La funcion grid cuadricula el axes sobre el figure 

# Asignando los valores para graficar en scatter, que nos imprime cada punto
fig = plt.scatter(x, y) 

# Asignamos nombres a los ejes
plt.xlabel('x') 
plt.ylabel('Sen(x)')

# Desplazara lo contenido que esta almacenado en Figure
plt.show()

# %% [markdown]
# El proceso basico para la creación de una constante:
#
# >* Obtener los datos X,Y. Que son arreglo de numpy.
# >* Crear un figure: plt.figure()
# >* Utilizar una función o un método de graficación: plt.plot()
# >* Desplegar la figure: plt.show()

# %% [markdown]
# Existe otra forma de graficar con mas metodos, esta es utlizando axes.  Axes es la clase que hace referencia a todo lo relacionado con la grafica.
#
# ### Axes
# Es la 'gráfica'.Es la región donde esta representado el espacio de datos. Un figur puede contener varios Axes pero un Axes solo puede ser contenido en un objeto Figure.
#
# Axes cuenta con los metodos, plot, scatter y subplot. Utilizados para la graficación de datos
#
# ### Axis
# Es la clase encargada de definir los limites de la grafica y generar la métrica (las marcas en cada eje), además de las etiquetas en cada marca.
#
#
# Todas las funciones para gráficar esperan recibir como parametros arreglos de NumPy.
#
# La primera llamada a la función plt.plot() creara el Figure necesario para poder agregar Axes. Una vez creado uno , siempre se reutilizara la figura que se creo por primera vez. En jupyter creará una figure por cada celda.

# %%
# Variable independiente
x = np.arange(0, 10, 0.2)

# Variable dependiente
y = np.sin(x)

# Creamos la figura
fig = plt.figure()

# Creamo un axes para tener en la figura
ax = plt.axes()
ax.set_xlabel("x")
ax.set_ylabel("Sen(x)")
ax.set_title("Hola ")
ax.grid()


# Utilizamos el metodo plot parra 
line = ax.plot(x, y)

# %% [markdown]
# ### Subplots
#
# Si queremos visualizar mas de una grafica en una misma figura podemos utilizar subplots.
#
# La función subplots retorna un Figure y Axes.
#
# Subplots recibe como parametros el numero de filas y columnas.
#
# plt.subplots(filas, columnas)
#
# Támbien podemos definir si comparten un eje.
#
# Con el parametro sharey(Compartir y) o sharex.

# %%
#First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

#Graficar solo una vez
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Simple plot')
plt.show()

# %%
#First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)


#Crea dos axes 
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True) # Retorna los Axes como tuplas
ax1.plot(x, y)
ax1.set_title('Compartiendo eje Y')
ax2.scatter(x, y)
plt.show()

# %%
#First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)


#Crer dos axes de manera vertical
fig, (ax3, ax4) = plt.subplots(2, 1, sharex=True) # 2 filas y una columna funcion subplots retorna una figure y axes
ax3.plot(x, y)
ax3.set_title('Compartiendo Eje X')
ax4.scatter(x, y)
plt.show()

# %% [markdown]
# ### Subplot
#
#
# Subplot es similar a subplots, agrega subplots a la figura. En cada subplot podemos utilizar una funcion plot para graficar.
#
# plt.subplot(numero de filas, numero de columnas, n- subplot)
#
# ![](../img/img_07.png)

# %%
t = np.arange(0.0, 2.0, 0.01)
s1 = np.sin(2*np.pi*t)
s2 = np.sin(4*np.pi*t)

# %%
plt.figure()
plt.subplot(211)
plt.plot(t, s1)
plt.subplot(212)
plt.scatter(t, 2*s1)
#The calling signature of add_subplot does not directly provide the option to place the axes at a predefined position

#In this example a new axes is created at the first position (1) on a grid of 2 rows and 3 columns.
# To produce only a single axes, add_subplot(111) would be used (First plot on a 1 by 1 subplot grid).
plt.show()

# %% [markdown]
# Con esta opción podríamos tener hasta cuatro gráficos con la siguiente distribución:
#
# ![Distribución de subplots](https://drive.google.com/uc?id=0B1rcny6-NX9FU2pDYmctSzgtNGM3aGxMc2toVWp2cEdKYVVF)

# %% [markdown]
# #Scatter plots

# %%
estaturaMujeres = [159, 160, 156, 169, 160, 173, 158, 162, 153, 154]
estaturaHombres = [176, 158, 169, 180, 176, 153, 163, 172, 160, 177]
rangoAlturas = np.linspace(150,190, num=10)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1]) # x0,y0,width,height
ax.scatter(rangoAlturas, estaturaMujeres , color='r')
ax.scatter(rangoAlturas, estaturaHombres, color='b')
ax.set_xlabel('Rango de estatura')
ax.set_ylabel('Estatura')
ax.set_title('scatter plot estatura hombres vs mujeres')
plt.show()

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30 * np.random.rand(N))**2
color = np.random.rand(N) * 20
plt.scatter(x, y, s = area, c = color) #s=marker size
plt.show()

# %%
#NOTA: Aquí los datos están en un diccionario, que es un tipo de dato inmutable que asocia dos tipos de datos como una llave:valor
data = {'Manzanas' : 11, 'Naranjas' :  15, 'Bananas' : 5, 'Guayabas' : 7}
nombre = list(data.keys())
valores = list(data.values())
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize = (8, 8), sharey = False)

ax1.bar(nombre, valores)
ax1.set_title('Grafica de barras ')

ax2.set_title('Grafica scatter')
ax2.set_xlabel('Frutas')
ax2.scatter(nombre, valores)


ax3.plot(nombre, valores)
ax3.set_title('Ploteando')

tamanos = np.array(valores)/sum(valores)

ax4.pie(tamanos, labels = nombre, autopct = '%.2f%%', shadow = True, startangle = 45 )
ax4.set_title('Diagrama de pastel')
ax4.axis('equal')

plt.show()

# %% [markdown]
# En resumen:
#
# ![texto alternativo](https://drive.google.com/uc?id=0B1rcny6-NX9FU1ljX0xDUVRGaTNmajQ3dTZEdXdLSmpVRHNF)
